# %%
import pandas as pd
import seaborn as sb

# %%
data = pd.read_csv(r'C:\Users\nari9\OneDrive\Documents\Projects\GenderModel\Data\wgnd_ctry.csv')

# %%
del data['gchar12']
del data['gchar1']
del data['gchar2']

# %%
print (data.head())
# Out:
# name code gender
# 0  A HANNAN   CA      M
# 1     A JAY   CA      M
# 2     A JAY   GB      M
# 3   A K I L   CA      M
# 4     A LAH   CA      F

# %%
print (data.describe())
# Out:
# name    code  gender
# count   290016  289848  290020
# unique  185923     172       3
# top      MARIA      US       F
# freq        46   96593  157293

# %%
data.isnull().any()
# Out:
# name       True
# code       True
# gender    False
# dtype: bool

# %%
data[data['name'].isnull()]
# Out:
#        name code gender
# 189076  NaN   CN      F
# 189077  NaN   GB      F
# 189078  NaN   KR      ?
# 189079  NaN   US      F

# %%
data.dropna(subset = ['name'], inplace = True)

# %%
data[data['name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [name, code, gender]
# Index: []

# %%
data[data['gender'].isnull()]
# Out:
# Empty DataFrame
# Columns: [name, code, gender]
# Index: []

# %%
data = data[data['name']<='zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz']

# %%
data['gender'] = data['gender'].map({'F': 1, 'M': 2, '?' : 0})
print (data)
# Out:
# name code  gender
# 0       A HANNAN   CA       2
# 1          A JAY   CA       2
# 2          A JAY   GB       2
# 3        A K I L   CA       2
# 4          A LAH   CA       1
# ...          ...  ...     ...
# 289451    ZYVION   US       2
# 289452      ZYXA   CA       1
# 289453   ZYYANNA   US       1
# 289454      ZZAK   CA       2
# 289455     ZZYZX   US       2
#
# [289452 rows x 3 columns]

# %%
del data['code']

# %%
data.describe()
# Out:
#               gender
# count  289452.000000
# mean        1.317928
# std         0.596909
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         2.000000

# %%
data.head()
# Out:
#        name  gender
# 0  A HANNAN       2
# 1     A JAY       2
# 2     A JAY       2
# 3   A K I L       2
# 4     A LAH       1

# %%
data['gender'].value_counts()
# Out:
# 1    157063
# 2    112207
# 0     20182
# Name: gender, dtype: int64

# %%
ndata = data['name'].duplicated(keep = False)

# %%
ndata =  (data[~ndata])

# %%
print (ndata)
# Out:
# name  gender
# 0       A HANNAN       2
# 3        A K I L       2
# 4          A LAH       1
# 5         A LIAN       0
# 6          A MEI       0
# ...          ...     ...
# 289451    ZYVION       2
# 289452      ZYXA       1
# 289453   ZYYANNA       1
# 289454      ZZAK       2
# 289455     ZZYZX       2
#
# [132512 rows x 2 columns]

# %%
ndata['gender'].value_counts()
# Out:
# 1    72731
# 2    49810
# 0     9971
# Name: gender, dtype: int64

# %%
newdataset = pd.DataFrame(columns=['name', 'gender'])

# %%
for row in ndata.itertuples():
    names = row[1].lower().split(" ")
    gender = row[2]
    print (names, gender)
# Out:
# ['A', 'HANNAN'] 2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\Tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-725c1ba14dd1> in <module>
# ...

# %%
# Out:
# a
# e
